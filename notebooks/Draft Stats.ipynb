# %%
import math
import pandas as pd
import re
import urllib.request

# %%
draft_url_format = 'http://dolphinsim.com/clmanager/epbl/year{0:04d}.txt'
draft_regex = re.compile('([0-9]+)\. ([a-z,A-Z,\s]*) draft ([0-9]+) ([A-Z]\.[A-Z][a-z,A-Z]+) \([A-Z]*.*\)<br>')
draft_list = {}
for season in range(58,90):
    print('Season {0:d}'.format(season))
    draft_url = draft_url_format.format(season)
    response = urllib.request.urlopen(draft_url)
    page = response.read()
    response.close()
    lines = page.decode("utf-8").split('\n')
    for line in lines:
        draft_matches = draft_regex.match(line)
        if draft_matches is not None:
            player_id = draft_matches.group(3)
            player_name = draft_matches.group(4)
            team_name = draft_matches.group(2)
            if team_name == 'Anaheim Angels':
                team_name = 'Anaheim'
            elif team_name == 'Arizona Diamondbacks':
                team_name = 'Arizona'
            elif team_name == 'Detroit Tigers':
                team_name = 'Detroit'
            draft_position = draft_matches.group(1)
            draft_round = math.ceil(int(draft_position)/30)
            round_position = int(draft_position) - (draft_round - 1) * 30
            
            if player_id not in draft_list.keys():
                draft_list[player_id] = {}
            draft_list[player_id]['player_name'] = player_name
            draft_list[player_id]['team_name'] = team_name
            draft_list[player_id]['draft_position'] = draft_position
            draft_list[player_id]['draft_round'] = draft_round
            draft_list[player_id]['round_position'] = round_position
            draft_list[player_id]['draft_season'] = season
# Out:
# Season 58
# Season 59
# Season 60
# Season 61
# Season 62
# Season 63
# Season 64
# Season 65
# Season 66
# Season 67
# Season 68
# Season 69
# Season 70
# Season 71
# Season 72
# Season 73
# Season 74
# Season 75
# Season 76
# Season 77
# Season 78
# Season 79
# Season 80
# Season 81
# Season 82
# Season 83
# Season 84
# Season 85
# Season 86
# Season 87
# Season 88
# Season 89

# %%
season_counts = {}
round_counts = {}
team_counts = {}

for player_id in draft_list.keys():
    if draft_list[player_id]['draft_season'] not in season_counts.keys():
        season_counts[draft_list[player_id]['draft_season']] = 1
    else:
        season_counts[draft_list[player_id]['draft_season']] += 1
        
    if draft_list[player_id]['draft_round'] not in round_counts.keys():
        round_counts[draft_list[player_id]['draft_round']] = 1
    else:
        round_counts[draft_list[player_id]['draft_round']] += 1
        
    if draft_list[player_id]['team_name'] not in team_counts.keys():
        team_counts[draft_list[player_id]['team_name']] = 1
    else:
        team_counts[draft_list[player_id]['team_name']] += 1
    
    #print('{} {} drafted in season {} with pick {} of round {} by {}'.format(player_id, draft_list[player_id]['player_name'],
    #                                                                        draft_list[player_id]['draft_season'], 
    #                                                                        draft_list[player_id]['round_position'],
    #                                                                        draft_list[player_id]['draft_round'],
    #                                                                        draft_list[player_id]['team_name']))
    
print('Season counts:')
for season in sorted(season_counts.keys()):
    print('{} from season {}'.format(season_counts[season], season))

print('\nRound counts:')
for draft_round in sorted(round_counts.keys()):
    print('{} from round {}'.format(round_counts[draft_round], draft_round))

print('\nTeam counts:')
for team_name in sorted(team_counts.keys()):
    print('{} from team {}'.format(team_counts[team_name], team_name))
# Out:
# Season counts:
# 1 from season 59
# 5 from season 63
# 5 from season 64
# 3 from season 66
# 11 from season 67
# 5 from season 68
# 5 from season 69
# 10 from season 70
# 27 from season 71
# 26 from season 72
# 36 from season 73
# 50 from season 74
# 50 from season 75
# 80 from season 76
# 77 from season 77
# 77 from season 78
# 97 from season 79
# 149 from season 80
# 210 from season 81
# 299 from season 82
# 385 from season 83
# 466 from season 84
# 584 from season 85
# 661 from season 86
# 900 from season 87
# 1376 from season 88
# 1500 from season 89
#
# Round counts:
# 409 from round 1
# 345 from round 2
# 317 from round 3
# 267 from round 4
# 273 from round 5
# 250 from round 6
# 252 from round 7
# 210 from round 8
# 212 from round 9
# 214 from round 10
# 200 from round 11
# 188 from round 12
# 179 from round 13
# 167 from round 14
# 172 from round 15
# 177 from round 16
# 155 from round 17
# 144 from round 18
# 152 from round 19
# 145 from round 20
# 135 from round 21
# 127 from round 22
# 133 from round 23
# 118 from round 24
# 122 from round 25
# 104 from round 26
# 109 from round 27
# 97 from round 28
# 110 from round 29
# 89 from round 30
# 85 from round 31
# 89 from round 32
# 89 from round 33
# 83 from round 34
# 83 from round 35
# 78 from round 36
# 76 from round 37
# 81 from round 38
# 82 from round 39
# 79 from round 40
# 71 from round 41
# 78 from round 42
# 77 from round 43
# 70 from round 44
# 70 from round 45
# 64 from round 46
# 72 from round 47
# 64 from round 48
# 64 from round 49
# 68 from round 50
#
# Team counts:
# 241 from team Anaheim
# 238 from team Arizona
# 188 from team Atlanta
# 225 from team Baltimore
# 229 from team Boston
# 292 from team Chicago AL
# 196 from team Chicago NL
# 246 from team Cincinnati
# 232 from team Cleveland
# 234 from team Colorado
# 282 from team Detroit
# 220 from team Florida
# 239 from team Houston
# 225 from team Kansas City
# 248 from team Los Angeles
# 221 from team Milwaukee
# 218 from team Minnesota
# 224 from team New York AL
# 260 from team New York NL
# 200 from team Oakland
# 227 from team Philadelphia
# 220 from team Pittsburgh
# 235 from team San Diego
# 244 from team San Francisco
# 252 from team Seattle
# 259 from team St Louis
# 251 from team Tampa Bay
# 239 from team Texas
# 225 from team Toronto
# 285 from team Washington

# %%
team_url_format = 'http://dolphinsim.com/clmanager/epbl/ros{0:03d}.htm'
words_regex = re.compile('\s+')
hist_url_regex = re.compile('.*<a href=\"(.*)\#([0-9]+)\">(.*)</a>.*')
age_regex = re.compile('([0-9]{2})r*')
team_by_level = {}    

class Player:
    def __init__(self, team, line):
        line = line.strip()
        url_matches = hist_url_regex.match(line)
        age_col = 3
        pos_col = 2
        name_col = 1
        id_col = 0
        attrs = words_regex.split(line)
        if url_matches is not None:
            self.history_url = url_matches.group(1)
            self.player_id = url_matches.group(2)
            self.name = url_matches.group(3)
            age_col += 1
            pos_col += 1
        else:
            self.history_url = None
            self.player_id = attrs[id_col].strip()
            self.name = attrs[name_col].strip()
            
        self.team = team
        self.age = 0
        self.draft_season = draft_list[self.player_id]['draft_season']
        self.draft_round = draft_list[self.player_id]['draft_round']
        self.draft_position = draft_list[self.player_id]['draft_position']
        self.draft_round_position = draft_list[self.player_id]['round_position']
        self.draft_team = draft_list[self.player_id]['team_name']
        if self.draft_team not in team_by_level.keys():
            team_by_level[self.draft_team] = {}
        if team.level not in team_by_level[self.draft_team].keys():
            team_by_level[self.draft_team][team.level] = 0
        team_by_level[self.draft_team][team.level] += 1
        self.position = attrs[pos_col].strip()
        age_matches = age_regex.match(attrs[age_col].strip())
        if age_matches is not None:
            self.age = age_matches.group(1)
            
    def __str__(self):
        draft_text = ' drafted by {0} in {1}, pick {2} of round {3}'.format(self.draft_team, self.draft_season, 
                                                                            self.draft_round_position, self.draft_round)
        if self.history_url is not None:
            return '<a href="{0}#{1}">{1}: {2}</a> {3} {4} {5}'.format(self.history_url, 
                                                                   self.player_id, self.name, 
                                                                   self.position, self.age,
                                                                   draft_text)
        return '{0}: {1} {2} {3} {4}'.format(self.player_id, self.name, self.position, self.age,
                                                                   draft_text)
    

class Team:
    def __init__(self, team_id, level='majors', parent='None'):
        self.team_id = team_id
        self.url = team_url_format.format(team_id)
        self.level = level
        print('{0}:{1} {2}'.format(team_id, level, self.url))
        self.parent = parent
        self.players = {}
        self.read_roster()
        if level == 'majors':
            self.aaa = Team(team_id + 30, 'AAA', self)
            self.aa = Team(team_id + 60, 'AA', self)
            self.hia = Team(team_id + 90, 'hi-A', self)
            self.a = Team(team_id + 120, 'A', self)
            self.hir = Team(team_id + 150, 'hi-R', self)
            self.r = Team(team_id + 180, 'R', self)
        
    def __str__(self):
        ret_str = '{0} ({1}): {2}'.format(self.name, self.level, self.url)
        if self.level == 'majors':
            ret_str += '\n\t{0}'.format(self.aaa.__str__())
            ret_str += '\n\t{0}'.format(self.aa.__str__())
            ret_str += '\n\t{0}'.format(self.hia.__str__())
            ret_str += '\n\t{0}'.format(self.a.__str__())
            ret_str += '\n\t{0}'.format(self.hir.__str__())
            ret_str += '\n\t{0}'.format(self.r.__str__())
        return ret_str
    
    def read_roster(self):
        response = urllib.request.urlopen(self.url)
        page = response.read()
        response.close()
        self.set_team_name(page)
        blocks = page.__str__().split('<pre>')
        block = 4
        if self.level != 'majors':
            block -= 1
        if self.level[:-1] == 'r':
            block -= 1
        attr_block = blocks[block].split('</pre>')[0]
        print(self.name)
        #print(self.name + '\n' + '\n'.join(attr_block.split('\\n')[:-1]) + '\n\n')
        self.process_block(attr_block)
        #print('\n')
        
    def process_block(self, block):
        lines = block.split('\\n')
        header = words_regex.split(lines[0])
        for line in lines[1:]:
            if len(line.strip()) == 0:
                continue
            player = Player(self, line)
            #print(player)
            self.players[player.player_id] = player
        
    def set_team_name(self, page):
        title = page.__str__().split('</title>')[0]
        title = title.split('<title>\\n')[1]
        self.name = title

            
teams = {}
for team_id in range(0,30):
    team = Team(team_id)
    teams[team.name] = team
    #print(team)
    #break
# Out:
# 0:majors http://dolphinsim.com/clmanager/epbl/ros000.htm
# Arizona
# 30:AAA http://dolphinsim.com/clmanager/epbl/ros030.htm
# Arizona
# 60:AA http://dolphinsim.com/clmanager/epbl/ros060.htm
# Arizona
# 90:hi-A http://dolphinsim.com/clmanager/epbl/ros090.htm
# Arizona
# 120:A http://dolphinsim.com/clmanager/epbl/ros120.htm
# Arizona
# 150:hi-R http://dolphinsim.com/clmanager/epbl/ros150.htm
# Arizona
# 180:R http://dolphinsim.com/clmanager/epbl/ros180.htm
# Arizona
# 1:majors http://dolphinsim.com/clmanager/epbl/ros001.htm
# Los Angeles
# 31:AAA http://dolphinsim.com/clmanager/epbl/ros031.htm
# Las Vegas
# 61:AA http://dolphinsim.com/clmanager/epbl/ros061.htm
# Jacksonville
# 91:hi-A http://dolphinsim.com/clmanager/epbl/ros091.htm
# Inland Empire
# 121:A http://dolphinsim.com/clmanager/epbl/ros121.htm
# Great Lakes
# 151:hi-R http://dolphinsim.com/clmanager/epbl/ros151.htm
# Ogden
# 181:R http://dolphinsim.com/clmanager/epbl/ros181.htm
# Los Angeles-R
# 2:majors http://dolphinsim.com/clmanager/epbl/ros002.htm
# San Francisco
# 32:AAA http://dolphinsim.com/clmanager/epbl/ros032.htm
# Fresno
# 62:AA http://dolphinsim.com/clmanager/epbl/ros062.htm
# Connecticut
# 92:hi-A http://dolphinsim.com/clmanager/epbl/ros092.htm
# San Jose
# 122:A http://dolphinsim.com/clmanager/epbl/ros122.htm
# Augusta
# 152:hi-R http://dolphinsim.com/clmanager/epbl/ros152.htm
# Salem-Keizer
# 182:R http://dolphinsim.com/clmanager/epbl/ros182.htm
# San Frncsco-R
# 3:majors http://dolphinsim.com/clmanager/epbl/ros003.htm
# Kansas City
# 33:AAA http://dolphinsim.com/clmanager/epbl/ros033.htm
# Omaha
# 63:AA http://dolphinsim.com/clmanager/epbl/ros063.htm
# NW Arkansas
# 93:hi-A http://dolphinsim.com/clmanager/epbl/ros093.htm
# Wilmington
# 123:A http://dolphinsim.com/clmanager/epbl/ros123.htm
# Lexington
# 153:hi-R http://dolphinsim.com/clmanager/epbl/ros153.htm
# Burlington
# 183:R http://dolphinsim.com/clmanager/epbl/ros183.htm
# Idaho Falls
# 4:majors http://dolphinsim.com/clmanager/epbl/ros004.htm
# Colorado
# 34:AAA http://dolphinsim.com/clmanager/epbl/ros034.htm
# Colorado Sprg
# 64:AA http://dolphinsim.com/clmanager/epbl/ros064.htm
# Tulsa
# 94:hi-A http://dolphinsim.com/clmanager/epbl/ros094.htm
# Modesto
# 124:A http://dolphinsim.com/clmanager/epbl/ros124.htm
# Asheville
# 154:hi-R http://dolphinsim.com/clmanager/epbl/ros154.htm
# Tri-City WA
# 184:R http://dolphinsim.com/clmanager/epbl/ros184.htm
# Casper
# 5:majors http://dolphinsim.com/clmanager/epbl/ros005.htm
# Houston
# 35:AAA http://dolphinsim.com/clmanager/epbl/ros035.htm
# Round Rock
# 65:AA http://dolphinsim.com/clmanager/epbl/ros065.htm
# Corpus Chrsti
# 95:hi-A http://dolphinsim.com/clmanager/epbl/ros095.htm
# Salem
# 125:A http://dolphinsim.com/clmanager/epbl/ros125.htm
# Lexington
# 155:hi-R http://dolphinsim.com/clmanager/epbl/ros155.htm
# Tri-City NY
# 185:R http://dolphinsim.com/clmanager/epbl/ros185.htm
# Greenville-R
# 6:majors http://dolphinsim.com/clmanager/epbl/ros006.htm
# Milwaukee
# 36:AAA http://dolphinsim.com/clmanager/epbl/ros036.htm
# Nashville
# 66:AA http://dolphinsim.com/clmanager/epbl/ros066.htm
# Huntsville
# 96:hi-A http://dolphinsim.com/clmanager/epbl/ros096.htm
# Brevard Cnty
# 126:A http://dolphinsim.com/clmanager/epbl/ros126.htm
# West Virginia
# 156:hi-R http://dolphinsim.com/clmanager/epbl/ros156.htm
# Helena
# 186:R http://dolphinsim.com/clmanager/epbl/ros186.htm
# Milwaukee-R
# 7:majors http://dolphinsim.com/clmanager/epbl/ros007.htm
# Minnesota
# 37:AAA http://dolphinsim.com/clmanager/epbl/ros037.htm
# Rochester
# 67:AA http://dolphinsim.com/clmanager/epbl/ros067.htm
# New Britain
# 97:hi-A http://dolphinsim.com/clmanager/epbl/ros097.htm
# Fort Myers
# 127:A http://dolphinsim.com/clmanager/epbl/ros127.htm
# Beloit
# 157:hi-R http://dolphinsim.com/clmanager/epbl/ros157.htm
# Elizabethton
# 187:R http://dolphinsim.com/clmanager/epbl/ros187.htm
# Minnesota-R
# 8:majors http://dolphinsim.com/clmanager/epbl/ros008.htm
# Chicago NL
# 38:AAA http://dolphinsim.com/clmanager/epbl/ros038.htm
# Iowa
# 68:AA http://dolphinsim.com/clmanager/epbl/ros068.htm
# Tennessee
# 98:hi-A http://dolphinsim.com/clmanager/epbl/ros098.htm
# Daytona
# 128:A http://dolphinsim.com/clmanager/epbl/ros128.htm
# Peoria
# 158:hi-R http://dolphinsim.com/clmanager/epbl/ros158.htm
# Boise
# 188:R http://dolphinsim.com/clmanager/epbl/ros188.htm
# Chicago NL-R
# 9:majors http://dolphinsim.com/clmanager/epbl/ros009.htm
# Chicago AL
# 39:AAA http://dolphinsim.com/clmanager/epbl/ros039.htm
# Chicago AL
# 69:AA http://dolphinsim.com/clmanager/epbl/ros069.htm
# Chicago AL
# 99:hi-A http://dolphinsim.com/clmanager/epbl/ros099.htm
# Chicago AL
# 129:A http://dolphinsim.com/clmanager/epbl/ros129.htm
# Chicago AL
# 159:hi-R http://dolphinsim.com/clmanager/epbl/ros159.htm
# Chicago AL
# 189:R http://dolphinsim.com/clmanager/epbl/ros189.htm
# Chicago AL
# 10:majors http://dolphinsim.com/clmanager/epbl/ros010.htm
# Cincinnati
# 40:AAA http://dolphinsim.com/clmanager/epbl/ros040.htm
# Louisville
# 70:AA http://dolphinsim.com/clmanager/epbl/ros070.htm
# Chattanooga
# 100:hi-A http://dolphinsim.com/clmanager/epbl/ros100.htm
# Sarasota
# 130:A http://dolphinsim.com/clmanager/epbl/ros130.htm
# Dayton
# 160:hi-R http://dolphinsim.com/clmanager/epbl/ros160.htm
# Billings
# 190:R http://dolphinsim.com/clmanager/epbl/ros190.htm
# Cincinnati-R
# 11:majors http://dolphinsim.com/clmanager/epbl/ros011.htm
# Atlanta
# 41:AAA http://dolphinsim.com/clmanager/epbl/ros041.htm
# Richmond
# 71:AA http://dolphinsim.com/clmanager/epbl/ros071.htm
# Mississippi
# 101:hi-A http://dolphinsim.com/clmanager/epbl/ros101.htm
# Myrtle Beach
# 131:A http://dolphinsim.com/clmanager/epbl/ros131.htm
# Rome
# 161:hi-R http://dolphinsim.com/clmanager/epbl/ros161.htm
# Danville
# 191:R http://dolphinsim.com/clmanager/epbl/ros191.htm
# Atlanta-R
# 12:majors http://dolphinsim.com/clmanager/epbl/ros012.htm
# Washington
# 42:AAA http://dolphinsim.com/clmanager/epbl/ros042.htm
# Columbus
# 72:AA http://dolphinsim.com/clmanager/epbl/ros072.htm
# Harrisburg
# 102:hi-A http://dolphinsim.com/clmanager/epbl/ros102.htm
# Potomac
# 132:A http://dolphinsim.com/clmanager/epbl/ros132.htm
# Hagerstown
# 162:hi-R http://dolphinsim.com/clmanager/epbl/ros162.htm
# Vermont
# 192:R http://dolphinsim.com/clmanager/epbl/ros192.htm
# Washington-R
# 13:majors http://dolphinsim.com/clmanager/epbl/ros013.htm
# Florida
# 43:AAA http://dolphinsim.com/clmanager/epbl/ros043.htm
# Albuquerque
# 73:AA http://dolphinsim.com/clmanager/epbl/ros073.htm
# Carolina
# 103:hi-A http://dolphinsim.com/clmanager/epbl/ros103.htm
# Jupiter
# 133:A http://dolphinsim.com/clmanager/epbl/ros133.htm
# Greensboro
# 163:hi-R http://dolphinsim.com/clmanager/epbl/ros163.htm
# Jamestown
# 193:R http://dolphinsim.com/clmanager/epbl/ros193.htm
# Florida-R
# 14:majors http://dolphinsim.com/clmanager/epbl/ros014.htm
# Tampa Bay
# 44:AAA http://dolphinsim.com/clmanager/epbl/ros044.htm
# Tampa Bay
# 74:AA http://dolphinsim.com/clmanager/epbl/ros074.htm
# Tampa Bay
# 104:hi-A http://dolphinsim.com/clmanager/epbl/ros104.htm
# Tampa Bay
# 134:A http://dolphinsim.com/clmanager/epbl/ros134.htm
# Tampa Bay
# 164:hi-R http://dolphinsim.com/clmanager/epbl/ros164.htm
# Tampa Bay
# 194:R http://dolphinsim.com/clmanager/epbl/ros194.htm
# Tampa Bay
# 15:majors http://dolphinsim.com/clmanager/epbl/ros015.htm
# Philadelphia
# 45:AAA http://dolphinsim.com/clmanager/epbl/ros045.htm
# Lehigh Valley
# 75:AA http://dolphinsim.com/clmanager/epbl/ros075.htm
# Reading
# 105:hi-A http://dolphinsim.com/clmanager/epbl/ros105.htm
# Clearwater
# 135:A http://dolphinsim.com/clmanager/epbl/ros135.htm
# Lakewood
# 165:hi-R http://dolphinsim.com/clmanager/epbl/ros165.htm
# Williamsport
# 195:R http://dolphinsim.com/clmanager/epbl/ros195.htm
# Philadlphia-R
# 16:majors http://dolphinsim.com/clmanager/epbl/ros016.htm
# Anaheim
# 46:AAA http://dolphinsim.com/clmanager/epbl/ros046.htm
# Anaheim
# 76:AA http://dolphinsim.com/clmanager/epbl/ros076.htm
# Anaheim
# 106:hi-A http://dolphinsim.com/clmanager/epbl/ros106.htm
# Anaheim
# 136:A http://dolphinsim.com/clmanager/epbl/ros136.htm
# Anaheim
# 166:hi-R http://dolphinsim.com/clmanager/epbl/ros166.htm
# Anaheim
# 196:R http://dolphinsim.com/clmanager/epbl/ros196.htm
# Anaheim
# 17:majors http://dolphinsim.com/clmanager/epbl/ros017.htm
# Oakland
# 47:AAA http://dolphinsim.com/clmanager/epbl/ros047.htm
# Sacramento
# 77:AA http://dolphinsim.com/clmanager/epbl/ros077.htm
# Midland
# 107:hi-A http://dolphinsim.com/clmanager/epbl/ros107.htm
# Stockton
# 137:A http://dolphinsim.com/clmanager/epbl/ros137.htm
# Kane County
# 167:hi-R http://dolphinsim.com/clmanager/epbl/ros167.htm
# Vancouver
# 197:R http://dolphinsim.com/clmanager/epbl/ros197.htm
# Oakland-R
# 18:majors http://dolphinsim.com/clmanager/epbl/ros018.htm
# Seattle
# 48:AAA http://dolphinsim.com/clmanager/epbl/ros048.htm
# Tacoma
# 78:AA http://dolphinsim.com/clmanager/epbl/ros078.htm
# West Tenn
# 108:hi-A http://dolphinsim.com/clmanager/epbl/ros108.htm
# High Desert
# 138:A http://dolphinsim.com/clmanager/epbl/ros138.htm
# Wisconsin
# 168:hi-R http://dolphinsim.com/clmanager/epbl/ros168.htm
# Everett
# 198:R http://dolphinsim.com/clmanager/epbl/ros198.htm
# Pulaski
# 19:majors http://dolphinsim.com/clmanager/epbl/ros019.htm
# Texas
# 49:AAA http://dolphinsim.com/clmanager/epbl/ros049.htm
# Oklahoma
# 79:AA http://dolphinsim.com/clmanager/epbl/ros079.htm
# Frisco
# 109:hi-A http://dolphinsim.com/clmanager/epbl/ros109.htm
# Bakersfield
# 139:A http://dolphinsim.com/clmanager/epbl/ros139.htm
# Clinton
# 169:hi-R http://dolphinsim.com/clmanager/epbl/ros169.htm
# Spokane
# 199:R http://dolphinsim.com/clmanager/epbl/ros199.htm
# Texas-R
# 20:majors http://dolphinsim.com/clmanager/epbl/ros020.htm
# Pittsburgh
# 50:AAA http://dolphinsim.com/clmanager/epbl/ros050.htm
# Indianapolis
# 80:AA http://dolphinsim.com/clmanager/epbl/ros080.htm
# Altoona
# 110:hi-A http://dolphinsim.com/clmanager/epbl/ros110.htm
# Lynchburg
# 140:A http://dolphinsim.com/clmanager/epbl/ros140.htm
# Hickory
# 170:hi-R http://dolphinsim.com/clmanager/epbl/ros170.htm
# State College
# 200:R http://dolphinsim.com/clmanager/epbl/ros200.htm
# Pittsburgh-R
# 21:majors http://dolphinsim.com/clmanager/epbl/ros021.htm
# Boston
# 51:AAA http://dolphinsim.com/clmanager/epbl/ros051.htm
# Boston
# 81:AA http://dolphinsim.com/clmanager/epbl/ros081.htm
# Boston
# 111:hi-A http://dolphinsim.com/clmanager/epbl/ros111.htm
# Boston
# 141:A http://dolphinsim.com/clmanager/epbl/ros141.htm
# Boston
# 171:hi-R http://dolphinsim.com/clmanager/epbl/ros171.htm
# Boston
# 201:R http://dolphinsim.com/clmanager/epbl/ros201.htm
# Boston
# 22:majors http://dolphinsim.com/clmanager/epbl/ros022.htm
# Detroit
# 52:AAA http://dolphinsim.com/clmanager/epbl/ros052.htm
# Toledo
# 82:AA http://dolphinsim.com/clmanager/epbl/ros082.htm
# Erie
# 112:hi-A http://dolphinsim.com/clmanager/epbl/ros112.htm
# Lakeland
# 142:A http://dolphinsim.com/clmanager/epbl/ros142.htm
# West Michigan
# 172:hi-R http://dolphinsim.com/clmanager/epbl/ros172.htm
# Oneonta
# 202:R http://dolphinsim.com/clmanager/epbl/ros202.htm
# Detroit-R
# 23:majors http://dolphinsim.com/clmanager/epbl/ros023.htm
# St Louis
# 53:AAA http://dolphinsim.com/clmanager/epbl/ros053.htm
# St Louis
# 83:AA http://dolphinsim.com/clmanager/epbl/ros083.htm
# St Louis
# 113:hi-A http://dolphinsim.com/clmanager/epbl/ros113.htm
# St Louis
# 143:A http://dolphinsim.com/clmanager/epbl/ros143.htm
# St Louis
# 173:hi-R http://dolphinsim.com/clmanager/epbl/ros173.htm
# St Louis
# 203:R http://dolphinsim.com/clmanager/epbl/ros203.htm
# St Louis
# 24:majors http://dolphinsim.com/clmanager/epbl/ros024.htm
# Cleveland
# 54:AAA http://dolphinsim.com/clmanager/epbl/ros054.htm
# Cleveland
# 84:AA http://dolphinsim.com/clmanager/epbl/ros084.htm
# Cleveland
# 114:hi-A http://dolphinsim.com/clmanager/epbl/ros114.htm
# Cleveland
# 144:A http://dolphinsim.com/clmanager/epbl/ros144.htm
# Cleveland
# 174:hi-R http://dolphinsim.com/clmanager/epbl/ros174.htm
# Cleveland
# 204:R http://dolphinsim.com/clmanager/epbl/ros204.htm
# Cleveland
# 25:majors http://dolphinsim.com/clmanager/epbl/ros025.htm
# Toronto
# 55:AAA http://dolphinsim.com/clmanager/epbl/ros055.htm
# Syracuse
# 85:AA http://dolphinsim.com/clmanager/epbl/ros085.htm
# New Hampshire
# 115:hi-A http://dolphinsim.com/clmanager/epbl/ros115.htm
# Dunedin
# 145:A http://dolphinsim.com/clmanager/epbl/ros145.htm
# Lansing
# 175:hi-R http://dolphinsim.com/clmanager/epbl/ros175.htm
# Auburn
# 205:R http://dolphinsim.com/clmanager/epbl/ros205.htm
# Toronto-R
# 26:majors http://dolphinsim.com/clmanager/epbl/ros026.htm
# New York AL
# 56:AAA http://dolphinsim.com/clmanager/epbl/ros056.htm
# Scranton W-B
# 86:AA http://dolphinsim.com/clmanager/epbl/ros086.htm
# Trenton
# 116:hi-A http://dolphinsim.com/clmanager/epbl/ros116.htm
# Tampa
# 146:A http://dolphinsim.com/clmanager/epbl/ros146.htm
# Charleston
# 176:hi-R http://dolphinsim.com/clmanager/epbl/ros176.htm
# Staten Island
# 206:R http://dolphinsim.com/clmanager/epbl/ros206.htm
# New York AL-R
# 27:majors http://dolphinsim.com/clmanager/epbl/ros027.htm
# Baltimore
# 57:AAA http://dolphinsim.com/clmanager/epbl/ros057.htm
# Norfolk
# 87:AA http://dolphinsim.com/clmanager/epbl/ros087.htm
# Bowie
# 117:hi-A http://dolphinsim.com/clmanager/epbl/ros117.htm
# Frederick
# 147:A http://dolphinsim.com/clmanager/epbl/ros147.htm
# Delmarva
# 177:hi-R http://dolphinsim.com/clmanager/epbl/ros177.htm
# Aberdeen
# 207:R http://dolphinsim.com/clmanager/epbl/ros207.htm
# Bluefield
# 28:majors http://dolphinsim.com/clmanager/epbl/ros028.htm
# San Diego
# 58:AAA http://dolphinsim.com/clmanager/epbl/ros058.htm
# El Paso
# 88:AA http://dolphinsim.com/clmanager/epbl/ros088.htm
# San Antonio
# 118:hi-A http://dolphinsim.com/clmanager/epbl/ros118.htm
# Lake Elsinore
# 148:A http://dolphinsim.com/clmanager/epbl/ros148.htm
# Fort Wayne
# 178:hi-R http://dolphinsim.com/clmanager/epbl/ros178.htm
# San Diego-HR
# 208:R http://dolphinsim.com/clmanager/epbl/ros208.htm
# San Diego-R
# 29:majors http://dolphinsim.com/clmanager/epbl/ros029.htm
# New York NL
# 59:AAA http://dolphinsim.com/clmanager/epbl/ros059.htm
# New York NL
# 89:AA http://dolphinsim.com/clmanager/epbl/ros089.htm
# New York NL
# 119:hi-A http://dolphinsim.com/clmanager/epbl/ros119.htm
# New York NL
# 149:A http://dolphinsim.com/clmanager/epbl/ros149.htm
# New York NL
# 179:hi-R http://dolphinsim.com/clmanager/epbl/ros179.htm
# New York NL
# 209:R http://dolphinsim.com/clmanager/epbl/ros209.htm
# New York NL
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-2b0517290c4e> in <module>()
#     124 for team in sorted(teams.keys()):
#     125     for level in ['majors', 'AAA', 'AA', 'hi-A', 'A', 'hi-R', 'R']:
# --> 126         print('{0} - {1}: {2:d}'.format(team.name, level, teams_by_level[team.name][level]))
#
# AttributeError: 'str' object has no attribute 'name'

# %%
for level in ['majors', 'AAA', 'AA', 'hi-A', 'A', 'hi-R', 'R']:
    for team in sorted(teams.keys()):
        print('{0} - {1}: {2:d}'.format(team, level, team_by_level[team][level]))
# Out:
# Anaheim - majors: 31
# Arizona - majors: 25
# Atlanta - majors: 35
# Baltimore - majors: 26
# Boston - majors: 20
# Chicago AL - majors: 40
# Chicago NL - majors: 20
# Cincinnati - majors: 27
# Cleveland - majors: 27
# Colorado - majors: 29
# Detroit - majors: 36
# Florida - majors: 31
# Houston - majors: 24
# Kansas City - majors: 26
# Los Angeles - majors: 24
# Milwaukee - majors: 21
# Minnesota - majors: 15
# New York AL - majors: 23
# New York NL - majors: 27
# Oakland - majors: 23
# Philadelphia - majors: 37
# Pittsburgh - majors: 17
# San Diego - majors: 30
# San Francisco - majors: 26
# Seattle - majors: 29
# St Louis - majors: 34
# Tampa Bay - majors: 22
# Texas - majors: 15
# Toronto - majors: 18
# Washington - majors: 21
# Anaheim - AAA: 21
# Arizona - AAA: 34
# Atlanta - AAA: 25
# Baltimore - AAA: 16
# Boston - AAA: 26
# Chicago AL - AAA: 31
# Chicago NL - AAA: 14
# Cincinnati - AAA: 32
# Cleveland - AAA: 15
# Colorado - AAA: 29
# Detroit - AAA: 31
# Florida - AAA: 16
# Houston - AAA: 15
# Kansas City - AAA: 29
# Los Angeles - AAA: 23
# Milwaukee - AAA: 18
# Minnesota - AAA: 17
# New York AL - AAA: 23
# New York NL - AAA: 27
# Oakland - AAA: 21
# Philadelphia - AAA: 17
# Pittsburgh - AAA: 22
# San Diego - AAA: 23
# San Francisco - AAA: 30
# Seattle - AAA: 27
# St Louis - AAA: 34
# Tampa Bay - AAA: 26
# Texas - AAA: 27
# Toronto - AAA: 31
# Washington - AAA: 30
# Anaheim - AA: 22
# Arizona - AA: 31
# Atlanta - AA: 21
# Baltimore - AA: 25
# Boston - AA: 25
# Chicago AL - AA: 23
# Chicago NL - AA: 20
# Cincinnati - AA: 30
# Cleveland - AA: 24
# Colorado - AA: 26
# Detroit - AA: 54
# Florida - AA: 24
# Houston - AA: 21
# Kansas City - AA: 21
# Los Angeles - AA: 27
# Milwaukee - AA: 22
# Minnesota - AA: 22
# New York AL - AA: 17
# New York NL - AA: 20
# Oakland - AA: 28
# Philadelphia - AA: 22
# Pittsburgh - AA: 19
# San Diego - AA: 19
# San Francisco - AA: 20
# Seattle - AA: 24
# St Louis - AA: 25
# Tampa Bay - AA: 25
# Texas - AA: 28
# Toronto - AA: 22
# Washington - AA: 40
# Anaheim - hi-A: 20
# Arizona - hi-A: 27
# Atlanta - hi-A: 13
# Baltimore - hi-A: 17
# Boston - hi-A: 28
# Chicago AL - hi-A: 42
# Chicago NL - hi-A: 16
# Cincinnati - hi-A: 26
# Cleveland - hi-A: 26
# Colorado - hi-A: 27
# Detroit - hi-A: 26
# Florida - hi-A: 18
# Houston - hi-A: 26
# Kansas City - hi-A: 23
# Los Angeles - hi-A: 34
# Milwaukee - hi-A: 27
# Minnesota - hi-A: 31
# New York AL - hi-A: 18
# New York NL - hi-A: 20
# Oakland - hi-A: 12
# Philadelphia - hi-A: 31
# Pittsburgh - hi-A: 15
# San Diego - hi-A: 26
# San Francisco - hi-A: 28
# Seattle - hi-A: 27
# St Louis - hi-A: 26
# Tampa Bay - hi-A: 27
# Texas - hi-A: 32
# Toronto - hi-A: 28
# Washington - hi-A: 33
# Anaheim - A: 16
# Arizona - A: 26
# Atlanta - A: 19
# Baltimore - A: 25
# Boston - A: 27
# Chicago AL - A: 27
# Chicago NL - A: 22
# Cincinnati - A: 27
# Cleveland - A: 32
# Colorado - A: 32
# Detroit - A: 31
# Florida - A: 20
# Houston - A: 23
# Kansas City - A: 29
# Los Angeles - A: 28
# Milwaukee - A: 17
# Minnesota - A: 32
# New York AL - A: 24
# New York NL - A: 10
# Oakland - A: 16
# Philadelphia - A: 24
# Pittsburgh - A: 24
# San Diego - A: 29
# San Francisco - A: 25
# Seattle - A: 26
# St Louis - A: 29
# Tampa Bay - A: 29
# Texas - A: 30
# Toronto - A: 22
# Washington - A: 29
# Anaheim - hi-R: 28
# Arizona - hi-R: 21
# Atlanta - hi-R: 15
# Baltimore - hi-R: 26
# Boston - hi-R: 24
# Chicago AL - hi-R: 23
# Chicago NL - hi-R: 21
# Cincinnati - hi-R: 25
# Cleveland - hi-R: 16
# Colorado - hi-R: 18
# Detroit - hi-R: 24
# Florida - hi-R: 26
# Houston - hi-R: 33
# Kansas City - hi-R: 34
# Los Angeles - hi-R: 23
# Milwaukee - hi-R: 33
# Minnesota - hi-R: 20
# New York AL - hi-R: 28
# New York NL - hi-R: 32
# Oakland - hi-R: 26
# Philadelphia - hi-R: 18
# Pittsburgh - hi-R: 32
# San Diego - hi-R: 23
# San Francisco - hi-R: 30
# Seattle - hi-R: 28
# St Louis - hi-R: 25
# Tampa Bay - hi-R: 22
# Texas - hi-R: 28
# Toronto - hi-R: 29
# Washington - hi-R: 19
# Anaheim - R: 35
# Arizona - R: 20
# Atlanta - R: 23
# Baltimore - R: 25
# Boston - R: 20
# Chicago AL - R: 28
# Chicago NL - R: 24
# Cincinnati - R: 27
# Cleveland - R: 29
# Colorado - R: 22
# Detroit - R: 18
# Florida - R: 31
# Houston - R: 30
# Kansas City - R: 23
# Los Angeles - R: 20
# Milwaukee - R: 24
# Minnesota - R: 25
# New York AL - R: 25
# New York NL - R: 25
# Oakland - R: 27
# Philadelphia - R: 24
# Pittsburgh - R: 20
# San Diego - R: 23
# San Francisco - R: 31
# Seattle - R: 26
# St Louis - R: 23
# Tampa Bay - R: 28
# Texas - R: 34
# Toronto - R: 18
# Washington - R: 19
